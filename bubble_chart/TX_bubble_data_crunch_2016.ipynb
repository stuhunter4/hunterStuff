# %%
import pandas as pd

# %%
election_csv = pd.read_csv("../county_data/resources/nytimes_presidential_elections_2016_results_county.csv")
census_csv = pd.read_csv("../county_data/resources/tx_county_facts_formatted.csv")

# %%
# list of counties, drop the 'County'
county_list = census_csv["County"].tolist()
for x in range(len(county_list)):
    county_list[x] = county_list[x].replace(" County", "")
print(county_list)
# Out:
# ['Anderson', 'Andrews', 'Angelina', 'Aransas', 'Archer', 'Armstrong', 'Atascosa', 'Austin', 'Bailey', 'Bandera', 'Bastrop', 'Baylor', 'Bee', 'Bell', 'Bexar', 'Blanco', 'Borden', 'Bosque', 'Bowie', 'Brazoria', 'Brazos', 'Brewster', 'Briscoe', 'Brooks', 'Brown', 'Burleson', 'Burnet', 'Caldwell', 'Calhoun', 'Callahan', 'Cameron', 'Camp', 'Carson', 'Cass', 'Castro', 'Chambers', 'Cherokee', 'Childress', 'Clay', 'Cochran', 'Coke', 'Coleman', 'Collin', 'Collingsworth', 'Colorado', 'Comal', 'Comanche', 'Concho', 'Cooke', 'Coryell', 'Cottle', 'Crane', 'Crockett', 'Crosby', 'Culberson', 'Dallam', 'Dallas', 'Dawson', 'Deaf Smith', 'Delta', 'Denton', 'DeWitt', 'Dickens', 'Dimmit', 'Donley', 'Duval', 'Eastland', 'Ector', 'Edwards', 'Ellis', 'El Paso', 'Erath', 'Falls', 'Fannin', 'Fayette', 'Fisher', 'Floyd', 'Foard', 'Fort Bend', 'Franklin', 'Freestone', 'Frio', 'Gaines', 'Galveston', 'Garza', 'Gillespie', 'Glasscock', 'Goliad', 'Gonzales', 'Gray', 'Grayson', 'Gregg', 'Grimes', 'Guadalupe', 'Hale', 'Hall', 'Hamilton', 'Hansford', 'Hardeman', 'Hardin', 'Harris', 'Harrison', 'Hartley', 'Haskell', 'Hays', 'Hemphill', 'Henderson', 'Hidalgo', 'Hill', 'Hockley', 'Hood', 'Hopkins', 'Houston', 'Howard', 'Hudspeth', 'Hunt', 'Hutchinson', 'Irion', 'Jack', 'Jackson', 'Jasper', 'Jeff Davis', 'Jefferson', 'Jim Hogg', 'Jim Wells', 'Johnson', 'Jones', 'Karnes', 'Kaufman', 'Kendall', 'Kenedy', 'Kent', 'Kerr', 'Kimble', 'King', 'Kinney', 'Kleberg', 'Knox', 'Lamar', 'Lamb', 'Lampasas', 'La Salle', 'Lavaca', 'Lee', 'Leon', 'Liberty', 'Limestone', 'Lipscomb', 'Live Oak', 'Llano', 'Loving', 'Lubbock', 'Lynn', 'McCulloch', 'McLennan', 'McMullen', 'Madison', 'Marion', 'Martin', 'Mason', 'Matagorda', 'Maverick', 'Medina', 'Menard', 'Midland', 'Milam', 'Mills', 'Mitchell', 'Montague', 'Montgomery', 'Moore', 'Morris', 'Motley', 'Nacogdoches', 'Navarro', 'Newton', 'Nolan', 'Nueces', 'Ochiltree', 'Oldham', 'Orange', 'Palo Pinto', 'Panola', 'Parker', 'Parmer', 'Pecos', 'Polk', 'Potter', 'Presidio', 'Rains', 'Randall', 'Reagan', 'Real', 'Red River', 'Reeves', 'Refugio', 'Roberts', 'Robertson', 'Rockwall', 'Runnels', 'Rusk', 'Sabine', 'San Augustine', 'San Jacinto', 'San Patricio', 'San Saba', 'Schleicher', 'Scurry', 'Shackelford', 'Shelby', 'Sherman', 'Smith', 'Somervell', 'Starr', 'Stephens', 'Sterling', 'Stonewall', 'Sutton', 'Swisher', 'Tarrant', 'Taylor', 'Terrell', 'Terry', 'Throckmorton', 'Titus', 'Tom Green', 'Travis', 'Trinity', 'Tyler', 'Upshur', 'Upton', 'Uvalde', 'Val Verde', 'Van Zandt', 'Victoria', 'Walker', 'Waller', 'Ward', 'Washington', 'Webb', 'Wharton', 'Wheeler', 'Wichita', 'Wilbarger', 'Willacy', 'Williamson', 'Wilson', 'Winkler', 'Wise', 'Wood', 'Yoakum', 'Young', 'Zapata', 'Zavala']

# %%
census_csv
# Out:
#               County Population Households  Persons per household  \
# 0    Anderson County     57,863     16,459                   2.69
# 1     Andrews County     17,818      5,508                   3.22
# 2    Angelina County     87,607     30,783                   2.75
# 3     Aransas County     24,763      9,432                   2.58
# 4      Archer County      8,789      3,332                   2.61
# ..               ...        ...        ...                    ...
# 249      Wood County     43,815     16,531                   2.56
# 250    Yoakum County      8,571      2,676                   3.20
# 251     Young County     18,114      7,105                   2.51
# 252    Zapata County     14,369      4,405                   3.25
# 253    Zavala County     12,131      3,509                   3.40
#
#      Households with a computer, percent  \
# 0                                   79.9
# 1                                   90.0
# 2                                   88.1
# 3                                   89.2
# 4                                   87.4
# ..                                   ...
# 249                                 85.3
# 250                                 87.6
# 251                                 86.4
# 252                                 80.6
# 253                                 70.8
#
#      Households with a broadband Internet subscription, percent  \
# 0                                                 66.2
# 1                                                 84.8
# 2                                                 79.3
# 3                                                 79.5
# 4                                                 74.8
# ..                                                 ...
# 249                                               75.6
# 250                                               73.3
# 251                                               71.7
# 252                                               54.1
# 253                                               48.3
#
#      Bachelor's degree or higher, percent of persons age 25+  \
# 0                                                 11.7
# 1                                                 10.4
# 2                                                 16.3
# 3                                                 21.7
# 4                                                 23.4
# ..                                                 ...
# 249                                               16.4
# 250                                               16.3
# 251                                               19.6
# 252                                               10.4
# 253                                                8.6
#
#     Median household income (in 2018 dollars)  \
# 0                                  $43,355.00
# 1                                  $74,233.00
# 2                                  $47,714.00
# 3                                  $44,865.00
# 4                                  $64,476.00
# ..                                        ...
# 249                                $48,534.00
# 250                                $68,814.00
# 251                                $47,194.00
# 252                                $31,113.00
# 253                                $30,988.00
#
#     Per capita income in 12 months (in 2018 dollars)  Poverty Rate  \
# 0                                         $16,868.00          11.3
# 1                                         $31,190.00          10.3
# 2                                         $22,322.00          17.7
# 3                                         $30,939.00          20.0
# 4                                         $31,806.00           9.2
# ..                                               ...           ...
# 249                                       $27,841.00          13.7
# 250                                       $26,519.00           9.0
# 251                                       $25,855.00          11.9
# 252                                       $17,228.00          39.0
# 253                                       $13,350.00          34.2
#
#     Population per square mile Total area in square miles
# 0                         53.7                    1,078.0
# 1                         11.9                   1,501.09
# 2                        101.3                     864.71
# 3                         46.9                     527.95
# 4                          9.5                     925.59
# ..                         ...                        ...
# 249                       63.0                     695.72
# 250                       10.7                     799.73
# 251                       19.5                     930.86
# 252                       13.6                   1,058.02
# 253                        9.3                   1,301.73
#
# [254 rows x 12 columns]

# %%
# filter election results for state of California only
tx_election = election_csv.loc[election_csv["State"] == "Texas"]

# list of votes for Clinton, Trump
election_group = tx_election.groupby(["Vote by county"])
clinton_list = election_group["Clinton"].sum().tolist()
trump_list = election_group["Trump"].sum().tolist()

# use list comprehension to add two lists
total_results = [clinton_list[i] + trump_list[i] for i in range(len(clinton_list))]

# same operation to get average vote for average vote per candidate
clinton_avg_list = [(clinton_list[j] / total_results[j])*100 for j in range(len(clinton_list))]
trump_avg_list = [(trump_list[k] / total_results[k])*100 for k in range(len(trump_list))]

# start with basic dataframe of data you are iterating through
election_df = pd.DataFrame({"Clinton": clinton_avg_list, "Trump": trump_avg_list})

# empty list for our results
election_list = []

# iterate over each row and append
for index, rows in election_df.iterrows():
    if rows["Clinton"] > rows["Trump"]:
        winner = rows["Clinton"] * -1
        election_list.append(winner)
    else:
        winner = rows["Trump"]
        election_list.append(winner)

# list of 2016 election winner per county, to designate colors
person_list = []
for n in range(len(election_list)):
    if election_list[n] > 0:
        person_list.append('rgba(255, 0, 0, 0.6)')
    else:
        person_list.append('rgba(0, 0, 255, 0.6)')

# %%
print(person_list)
# Out:
# ['rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(0, 0, 255, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0, 0.6)', 'rgba(255, 0, 0 ...

# %%
pop_list = census_csv["Population"].tolist()
popd_list = census_csv["Population per square mile"].tolist()
ed_list = census_csv["Bachelor's degree or higher, percent of persons age 25+"].tolist()
print(pop_list)
print(popd_list)
print(ed_list)
# Out:
# ['57,863', '17,818', '87,607', '24,763', '8,789', '1,916', '48,828', '29,565', '7,092', '21,763', '82,577', '3,591', '32,691', '342,236', '1,925,865', '11,279', '665', '18,122', '93,858', '353,999', '219,193', '9,216', '1,546', '7,180', '37,834', '17,863', '45,750', '41,401', '21,807', '13,770', '421,750', '12,813', '6,032', '30,087', '7,787', '40,292', '51,903', '7,226', '10,387', '2,904', '3,275', '8,391', '944,350', '2,996', '21,022', '135,097', '13,495', '4,233', '39,571', '75,389', '1,623', '4,839', '3,633', '5,861', '2,241', '7,243', '2,586,552', '12,964', '18,899', '5,215', '807,047', '20,435', '2,216', '10,663', '3,387', '11,355', '18,270', '158,342', '2,055', '168,838', '837,654', '41,482', '17,299', '34,175', '25,066', '3,883', '5,872', '1,408', '739,342', '10,679', '19,709', '19,394', '20,321', '327,089', '6,288', '26,208', '1,430', '7,531', '20,667', '22,685', '128,560', '123,494', '27,630', '155,137', '34,113', '3,074', '8,269', '5,547', '3,952', '56,379', '4,602,523', '66,645', '5,767', '5,809', '204,150', '4,061', '80,460', '849,389', '35,399', '23,162', '56,901', '36,240', '22,955', '36,667', '4,098', '92,152', '21,571', '1,524', '8,842', '14,820', '35,504', '2,234', '255,210', '5,282', '41,192', '163,475', '19,891', '15,387', '118,910', '41,982', '595', '749', '51,365', '4,408', '228', '3,675', '31,425', '3,733', '49,532', '13,262', '20,640', '7,409', '19,941', '16,952', '17,098', '81,862', '23,515', '3,469', '12,123', '20,640', '102', '301,454', '5,808', '8,098', '248,429', '662', '14,128', '10,083', '5,614', '4,161', '36,743', '57,970', '49,334', '2,123', '164,194', '24,664', '4,902', '8,558', '19,409', '554,445', '21,801', '12,424', '1,156', '65,558', '48,583', '14,057', '14,966', '360,486', '10,348', '2,090', '84,047', '28,317', '23,440', '129,802', '9,852', '15,797', '47,837', '120,899', '7,123', '11,473', '132,475', '3,752', '3,389', '12,275', '15,125', '7,236', '885', '16,890', '93,642', '10,310', '53,595', '10,458', '8,327', '27,819', '67,046', '5,962', '3,061', '17,239', '3,311', '25,478', '3,058', '225,015', '8,743', '63,894', '9,372', '1,141', '1,385', '3,865', '7,484', '2,019,977', '136,348', '862', '12,615', '1,567', '32,730', '117,466', '1,203,166', '14,569', '21,496', '40,769', '3,634', '27,009', '49,027', '54,368', '91,970', '71,539', '49,987', '11,586', '34,796', '272,053', '41,551', '5,482', '131,818', '12,906', '21,754', '527,057', '48,198', '7,802', '64,639', '43,815', '8,571', '18,114', '14,369', '12,131']
# ['53.7', '11.9', '101.3', '46.9', '9.5', '2.1', '40.0', '45.0', '8.6', '27.3', '92.2', '4.0', '37.1', '314.6', '1,533.2', '15.8', '0.7', '18.1', '101.7', '220.1', '370.7', '1.5', '1.7', '7.6', '39.5', '26.4', '44.8', '75.7', '21.1', '15.3', '330.4', '63.0', '6.5', '31.3', '8.7', '46.2', '48.9', '10.1', '9.3', '3.7', '3.5', '6.5', '1,065.7', '3.3', '21.6', '235.0', '14.2', '4.3', '44.0', '71.3', '1.8', '6.2', '1.3', '6.5', '0.6', '4.8', '2,846.7', '14.4', '12.6', '18.8', '846.9', '22.4', '2.4', '8.0', '3.6', '6.3', '19.6', '175.6', '1.0', '177.4', '825.0', '38.1', '22.4', '38.0', '26.1', '4.3', '5.9', '2.0', '835.1', '36.2', '22.1', '17.1', '13.5', '374.3', '7.0', '24.7', '1.6', '8.8', '19.3', '24.4', '131.3', '447.8', '34.5', '217.0', '34.0', '3.4', '9.9', '6.0', '5.7', '62.8', '2,589.3', '72.8', '3.9', '6.4', '300.3', '4.5', '84.8', '536.6', '35.9', '25.5', '130.3', '45.7', '18.6', '40.6', '0.9', '104.5', '24.1', '1.4', '9.6', '17.3', '36.6', '1.0', '229.4', '4.6', '47.4', '222.6', '21.2', '20.4', '147.2', '63.3', '0.3', '0.8', '46.4', '3.5', '0.2', '2.7', '28.8', '4.4', '53.1', '13.0', '28.9', '5.0', '20.5', '26.7', '15.8', '69.6', '25.2', '3.7', '11.2', '21.4', '0.2', '334.7', '6.5', '7.5', '234.3', '0.6', '29.9', '24.0', '6.1', '4.5', '22.8', '44.9', '37.0', '2.4', '182.0', '24.1', '6.5', '9.3', '20.7', '514.9', '24.0', '48.0', '1.2', '66.8', '44.7', '15.0', '16.4', '309.3', '11.3', '1.4', '221.5', '28.7', '28.5', '142.6', '11.1', '3.3', '43.1', '131.1', '1.8', '44.3', '143.6', '3.2', '4.8', '11.6', '5.7', '8.8', '1.0', '19.5', '629.5', '9.8', '57.1', '18.1', '14.1', '44.3', '94.7', '5.2', '2.3', '19.0', '3.6', '30.5', '3.3', '236.9', '45.5', '52.0', '10.2', '1.2', '1.5', '2.7', '8.3', '2,238.7', '148.3', '0.4', '14.2', '1.7', '76.9', '76.2', '1,176.1', '20.4', '23.0', '68.8', '2.9', '17.3', '15.2', '63.2', '103.5', '89.3', '96.5', '13.9', '56.0', '80.6', '38.0', '6.0', '208.3', '13.2', '27.7', '464.6', '59.6', '9.3', '70.1', '63.0', '10.7', '19.5', '13.6', '9.3']
# [11.7, 10.4, 16.3, 21.7, 23.4, 23.2, 13.3, 23.5, 17.7, 23.8, 20.4, 19.7, 10.2, 24.5, 27.6, 27.1, 35.0, 18.5, 19.9, 29.7, 40.8, 39.4, 22.7, 17.6, 19.3, 17.1, 25.1, 14.8, 15.0, 19.1, 17.3, 18.6, 30.4, 16.4, 14.8, 21.5, 16.9, 17.3, 18.6, 8.2, 17.1, 15.6, 51.7, 18.4, 18.6, 35.3, 19.8, 11.9, 20.5, 15.7, 15.3, 12.4, 14.1, 12.8, 9.0, 13.6, 30.7, 12.5, 12.2, 21.3, 44.5, 12.8, 16.7, 14.1, 19.8, 9.3, 13.3, 15.6, 20.8, 23.1, 22.8, 29.7, 12.9, 16.7, 18.1, 18.2, 15.9, 16.2, 46.1, 23.6, 13.0, 7.2, 12.4, 30.0, 13.9, 33.8, 23.2, 17.6, 12.3, 13.3, 20.5, 20.8, 14.6, 27.5, 16.5, 14.3, 21.7, 14.3, 14.5, 15.3, 31.0, 19.1, 17.2, 13.4, 37.4, 21.0, 18.2, 18.4, 17.1, 14.0, 26.1, 18.3, 14.1, 12.3, 6.9, 19.3, 13.8, 16.9, 12.6, 16.1, 12.4, 35.1, 19.6, 12.3, 12.7, 18.3, 11.5, 14.4, 20.7, 40.9, 6.8, 23.6, 25.6, 22.1, 18.2, 9.6, 24.8, 19.6, 17.6, 15.9, 20.0, 13.1, 16.7, 15.9, 16.4, 9.5, 14.0, 19.5, 13.2, 25.7, 0.0, 29.1, 18.2, 19.0, 23.7, 23.3, 13.6, 14.9, 20.4, 20.0, 16.7, 12.5, 19.8, 17.8, 27.4, 13.8, 18.2, 11.8, 15.5, 34.7, 14.3, 15.5, 16.7, 24.5, 16.1, 8.9, 15.5, 21.5, 15.2, 22.5, 15.3, 16.5, 15.5, 26.8, 17.7, 9.8, 14.0, 14.8, 20.1, 11.7, 32.0, 10.6, 20.6, 12.6, 10.8, 11.8, 26.3, 16.1, 40.3, 18.3, 14.5, 16.0, 13.3, 10.9, 14.9, 14.4, 16.5, 16.5, 24.9, 14.5, 19.7, 25.8, 23.9, 10.3, 16.6, 15.9, 13.7, 17.7, 12.8, 31.5, 24.5, 15.3, 12.0, 19.0, 15.9, 24.2, 48.6, 12.8, 12.5, 17.0, 9.9, 15.8, 18.6, 17.1, 20.1, 20.6, 19.9, 13.6, 25.0, 18.4, 17.1, 16.6, 23.0, 16.1, 10.1, 41.1, 20.5, 9.5, 17.5, 16.4, 16.3, 19.6, 10.4, 8.6]

# %%
# prepare dataframe for plotly.express chart
df = pd.DataFrame({"Population per square mile": popd_list, "Bachelor's degree or higher, percent of persons age 25+": ed_list,
                     "Population": pop_list, "2016 Winner": person_list, "County": county_list})

# %%
import json
# use .to_dict and 'records' orient to make our desired list
# can be used as 'data.js', or .insert_many with PyMongo
list_d = df.to_dict(orient='records')

# %%
# write to a text file for our data.js file
with open("weekly_dict.txt", "w") as file:
    file.write(json.dumps(list_d))
