# %%
import pandas as pd

# %%
# read in the csv file
data = pd.read_csv("census_plotly_personal/Resources/Local_Area_Unemployment_Statistics__LAUS_.csv")

# %%
data
# Out:
#        Area Type          Area Name       Date  Year       Month  \
# 0           State         California  1/1/1976   1976    January
# 1           State         California  1/1/1977   1977    January
# 2           State         California  1/1/1978   1978    January
# 3           State         California  1/1/1979   1979    January
# 4           State         California  1/1/1980   1980    January
# ...           ...                ...       ...    ...        ...
# 165040        MSA  Yuba City, CA MSA  5/1/2020   2020        May
# 165041        MSA  Yuba City, CA MSA  6/1/2020   2020       June
# 165042        MSA  Yuba City, CA MSA  7/1/2020   2020       July
# 165043        MSA  Yuba City, CA MSA  8/1/2020   2020     August
# 165044        MSA  Yuba City, CA MSA  9/1/2020   2020  September
#
#        Seasonally Adjusted (Y/N)  Status (Preliminary / Final)   Labor Force  \
# 0                               Y                         Final      9734600
# ...

# %%
data = data.loc[(data["Area Type "] == "County") & (data["Date"] == "8/1/2020")]
data
# Out:
#        Area Type               Area Name       Date  Year    Month  \
# 103675     County          Alameda County  8/1/2020   2020  August
# 103676     County           Alpine County  8/1/2020   2020  August
# 103677     County           Amador County  8/1/2020   2020  August
# 103678     County            Butte County  8/1/2020   2020  August
# 103679     County        Calaveras County  8/1/2020   2020  August
# 103680     County           Colusa County  8/1/2020   2020  August
# 103681     County     Contra Costa County  8/1/2020   2020  August
# 103682     County        Del Norte County  8/1/2020   2020  August
# 103683     County        El Dorado County  8/1/2020   2020  August
# 103684     County           Fresno County  8/1/2020   2020  August
# 103685     County            Glenn County  8/1/2020   2020  August
# 103686     County         Humboldt County  8/1/2020   2020  August
# 103687     County         Imperial County  8/1/2020   2020  August
# ...

# %%
urate = data[["Area Name ", "Unemployment Rate "]]
urate = urate.reset_index(drop=True)
urate
# Out:
#                 Area Name   Unemployment Rate
# 0           Alameda County               0.095
# 1            Alpine County               0.104
# 2            Amador County               0.089
# 3             Butte County               0.086
# 4         Calaveras County               0.072
# 5            Colusa County               0.104
# 6      Contra Costa County               0.094
# 7         Del Norte County               0.090
# 8         El Dorado County               0.076
# 9            Fresno County               0.103
# 10            Glenn County               0.077
# 11         Humboldt County               0.082
# 12         Imperial County               0.220
# 13             Inyo County               0.072
# 14             Kern County               0.124
# 15            Kings County               0.101
# 16             Lake County               0.085
# 17           Lassen County               0.064
# 18      Los Angeles County               0.168
# ...

# %%
urate.to_csv("CA_Counties_LAUS_82020.csv", index=False, header=True)
