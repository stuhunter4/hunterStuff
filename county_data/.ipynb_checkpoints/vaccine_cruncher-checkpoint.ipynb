# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read in cases dataset for population information
new_cases = pd.read_csv("resources/covid19cases_test.csv")

# %%
# remove rows that are not counties or California
clean_cases = new_cases.loc[ (new_cases["area"] != "Unknown") & (new_cases["area"] != "Out of state")]

# %%
# create list of population values
populations = clean_cases["population"].unique().tolist()
print(populations)
# Out:
# [1685886.0, 1117.0, 38531.0, 217769.0, 44289.0, 40129160.0, 22593.0, 1160099.0, 27558.0, 193098.0, 1032227.0, 29348.0, 134098.0, 191649.0, 18453.0, 927251.0, 156444.0, 64871.0, 30065.0, 10257557.0, 160089.0, 260800.0, 17795.0, 88439.0, 287420.0, 9475.0, 13961.0, 448732.0, 139652.0, 98710.0, 3228519.0, 400434.0, 18997.0, 2468145.0, 1567975.0, 64022.0, 2217398.0, 3370418.0, 892280.0, 782545.0, 278862.0, 778001.0, 456373.0, 1967585.0, 273999.0, 177925.0, 3115.0, 43956.0, 444255.0, 496668.0, 562303.0, 105747.0, 65885.0, 13354.0, 484423.0, 52351.0, 852747.0, 223612.0, 79290.0]

# %%
# display the end of the DataFrame for most recent date
new_vacc = pd.read_csv("resources/covid19vaccinesbycounty.csv")
new_vacc.tail(5)
# Out:
#       county administered_date  total_doses  cumulative_total_doses  \
# 5420  Amador        2021-03-15          179                   14676
# 5421  Amador        2021-03-16          453                   15129
# 5422  Amador        2021-03-17          171                   15300
# 5423  Amador        2021-03-18          132                   15432
# 5424  Amador        2021-03-19          136                   15568
#
#       pfizer_doses  cumulative_pfizer_doses  moderna_doses  \
# 5420            22                     4311            146
# 5421            58                     4369            391
# 5422            33                     4402            135
# 5423            72                     4474             57
# 5424            23                     4497            106
#
#       cumulative_moderna_doses  jj_doses  cumulative_jj_doses  \
# 5420                     10327        11                   38
# 5421                     10718         4                   42
# 5422                     10853         3                   45
# 5423                     10910         3                   48
# 5424                     11016         7                   55
#
#       partially_vaccinated  total_partially_vaccinated  fully_vaccinated  \
# 5420                    54                        7017               125
# 5421                   195                        6964               255
# 5422                   108                        7014                63
# 5423                    84                        7058                47
# 5424                    74                        7080                61
#
#       cumulative_fully_vaccinated  at_least_one_dose  \
# 5420                         3934                 79
# 5421                         4189                202
# 5422                         4252                113
# 5423                         4299                 91
# 5424                         4360                 83
#
#       cumulative_at_least_one_dose california_flag
# 5420                         10951      California
# 5421                         11153      California
# 5422                         11266      California
# 5423                         11357      California
# 5424                         11440      California

# %%
# create variable for the last date
last_date = '2021-03-19'

# %%
# create DataFrames with only the most recent entries for 'cumulative_fully_vaccinated'
cali_df = new_vacc.loc[new_vacc.administered_date == f'{last_date}']
vacc_df = new_vacc.loc[(new_vacc.administered_date == f'{last_date}')&\
                      (new_vacc.county != 'Outside California') & (new_vacc.county != 'Unknown')]
cali_df = cali_df[['county', 'administered_date', 'cumulative_fully_vaccinated']]
vacc_df = vacc_df[['county', 'administered_date', 'cumulative_fully_vaccinated']]

# %%
# calculate totals for California, including out-of-state residents vaccinated in California
total_full = cali_df.cumulative_fully_vaccinated.sum()
# create dictionary to append to vaccine DataFrame
vacc_ca = {'county': 'California', 'administered_date': f'{last_date}',
           'cumulative_fully_vaccinated': total_full}

# %%
# append a row for California data
vacc_df = vacc_df.append(vacc_ca, ignore_index=True)

# %%
# sort DataFrame alphabetically by county
vacc_df = vacc_df.sort_values("county")
# reset index
vacc_df = vacc_df.reset_index(drop=True)
# add population data to DataFrame
vacc_df['population'] = populations
# convert population floats to integers
vacc_df['population'] = vacc_df['population'].astype(int)

# %%
# create columns for percent of population vaccinated
vacc_df['percent_full'] = round((vacc_df.cumulative_fully_vaccinated / vacc_df.population) * 100, 2)

# %%
# verification
vacc_df
# Out:
#              county administered_date  cumulative_fully_vaccinated  \
# 0           Alameda        2021-03-19                       242233
# 1            Alpine        2021-03-19                          270
# 2            Amador        2021-03-19                         4360
# 3             Butte        2021-03-19                        31846
# 4         Calaveras        2021-03-19                         6137
# 5        California        2021-03-19                      5009299
# 6            Colusa        2021-03-19                         1963
# 7      Contra Costa        2021-03-19                       181120
# 8         Del Norte        2021-03-19                         2153
# 9         El Dorado        2021-03-19                        24871
# 10           Fresno        2021-03-19                        90238
# 11            Glenn        2021-03-19                         3580
# 12         Humboldt        2021-03-19                        18505
# 13         Imperial        2021-03-19                        15302
# 14             Inyo        2021-03-19                         3481
# 15             Kern        2021-03-19                        73932
# 16            Kings        2021-03-19                         7375
# 17             Lake        2021-03-19                         8764
# 18           Lassen        2021-03-19                         2308
# 19      Los Angeles        2021-03-19                      1177454
# 20           Madera        2021-03-19                        14446
# 21            Marin        2021-03-19                        50362
# 22         Mariposa        2021-03-19                         1477
# 23        Mendocino        2021-03-19                        15356
# 24           Merced        2021-03-19                        20632
# 25            Modoc        2021-03-19                         1551
# 26             Mono        2021-03-19                         3941
# 27         Monterey        2021-03-19                        42991
# 28             Napa        2021-03-19                        25519
# 29           Nevada        2021-03-19                        13226
# 30           Orange        2021-03-19                       418785
# 31           Placer        2021-03-19                        62193
# 32           Plumas        2021-03-19                         2167
# 33        Riverside        2021-03-19                       258806
# 34       Sacramento        2021-03-19                       172642
# 35       San Benito        2021-03-19                         4970
# 36   San Bernardino        2021-03-19                       200230
# 37        San Diego        2021-03-19                       546357
# 38    San Francisco        2021-03-19                       133739
# 39      San Joaquin        2021-03-19                        74882
# 40  San Luis Obispo        2021-03-19                        41190
# 41        San Mateo        2021-03-19                       119367
# 42    Santa Barbara        2021-03-19                        51626
# 43      Santa Clara        2021-03-19                       252420
# 44       Santa Cruz        2021-03-19                        44933
# 45           Shasta        2021-03-19                        16391
# 46           Sierra        2021-03-19                          759
# 47         Siskiyou        2021-03-19                         5741
# 48           Solano        2021-03-19                        49571
# 49           Sonoma        2021-03-19                        86985
# 50       Stanislaus        2021-03-19                        57472
# 51           Sutter        2021-03-19                        11074
# 52           Tehama        2021-03-19                         5445
# 53          Trinity        2021-03-19                         1510
# 54           Tulare        2021-03-19                        36305
# 55         Tuolumne        2021-03-19                         8169
# 56          Ventura        2021-03-19                       102543
# 57             Yolo        2021-03-19                        29452
# 58             Yuba        2021-03-19                         5650
#
#     population  percent_full
# 0      1685886         14.37
# 1         1117         24.17
# 2        38531         11.32
# 3       217769         14.62
# 4        44289         13.86
# 5     40129160         12.48
# 6        22593          8.69
# 7      1160099         15.61
# 8        27558          7.81
# 9       193098         12.88
# 10     1032227          8.74
# 11       29348         12.20
# 12      134098         13.80
# 13      191649          7.98
# 14       18453         18.86
# 15      927251          7.97
# 16      156444          4.71
# 17       64871         13.51
# 18       30065          7.68
# 19    10257557         11.48
# 20      160089          9.02
# 21      260800         19.31
# 22       17795          8.30
# 23       88439         17.36
# 24      287420          7.18
# 25        9475         16.37
# 26       13961         28.23
# 27      448732          9.58
# 28      139652         18.27
# 29       98710         13.40
# 30     3228519         12.97
# 31      400434         15.53
# 32       18997         11.41
# 33     2468145         10.49
# 34     1567975         11.01
# 35       64022          7.76
# 36     2217398          9.03
# 37     3370418         16.21
# 38      892280         14.99
# 39      782545          9.57
# 40      278862         14.77
# 41      778001         15.34
# 42      456373         11.31
# 43     1967585         12.83
# 44      273999         16.40
# 45      177925          9.21
# 46        3115         24.37
# 47       43956         13.06
# 48      444255         11.16
# 49      496668         17.51
# 50      562303         10.22
# 51      105747         10.47
# 52       65885          8.26
# 53       13354         11.31
# 54      484423          7.49
# 55       52351         15.60
# 56      852747         12.03
# 57      223612         13.17
# 58       79290          7.13

# %%
import json

# %%
# use .to_dict and 'records' orient to make our desired list
# can be used as 'data.js', or .insert_many with PyMongo
list_d = vacc_df.to_dict(orient='records')

# %%
# write to a text file for our data.js later
with open("weekly_dict.txt", "w") as file:
    file.write(json.dumps(list_d))
